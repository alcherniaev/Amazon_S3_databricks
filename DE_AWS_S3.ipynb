# %%
dbutils.fs.unmount("/mnt/s3data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/s3data has been unmounted.
# Out[49]: True</div>

# %%
from urllib import parse
ACCESS_KEY = "X"
SECRET_KEY = "J"
ENCODED_SECRET_KEY = urllib.parse.quote(SECRET_KEY, "")
AWS_BUCKET_NAME = "databricks-airbnb-ch"
MOUNT_NAME = "s3data"
dbutils.fs.mount("s3n://%s:%s@%s" % (ACCESS_KEY, ENCODED_SECRET_KEY, AWS_BUCKET_NAME), "/mnt/%s" % MOUNT_NAME)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: True</div>

# %%
 display(dbutils.fs.ls("/mnt/s3data"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/s3data/listings.csv</td><td>listings.csv</td><td>5962518</td></tr><tr><td>dbfs:/mnt/s3data/neighbourhoods.csv</td><td>neighbourhoods.csv</td><td>242</td></tr><tr><td>dbfs:/mnt/s3data/reviews.csv</td><td>reviews.csv</td><td>22432792</td></tr></tbody></table></div>

# %%
# file location and type
file_location = "dbfs:/mnt/s3data/listings.csv"
file_type = "csv"

# CV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. 
df_listing = spark.read.format(file_type) \
                  .option("infer_schema", infer_schema) \
                  .option("header", first_row_is_header) \
                  .option("sep", delimiter) \
                  .load(file_location)

display(df_listing.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>listing_url</th><th>scrape_id</th><th>last_scraped</th><th>name</th><th>description</th><th>neighborhood_overview</th><th>picture_url</th><th>host_id</th><th>host_url</th><th>host_name</th><th>host_since</th><th>host_location</th><th>host_about</th><th>host_response_time</th><th>host_response_rate</th><th>host_acceptance_rate</th><th>host_is_superhost</th><th>host_thumbnail_url</th><th>host_picture_url</th><th>host_neighbourhood</th><th>host_listings_count</th><th>host_total_listings_count</th><th>host_verifications</th><th>host_has_profile_pic</th><th>host_identity_verified</th><th>neighbourhood</th><th>neighbourhood_cleansed</th><th>neighbourhood_group_cleansed</th><th>latitude</th><th>longitude</th><th>property_type</th><th>room_type</th><th>accommodates</th><th>bathrooms</th><th>bathrooms_text</th><th>bedrooms</th><th>beds</th><th>amenities</th><th>price</th><th>minimum_nights</th><th>maximum_nights</th><th>minimum_minimum_nights</th><th>maximum_minimum_nights</th><th>minimum_maximum_nights</th><th>maximum_maximum_nights</th><th>minimum_nights_avg_ntm</th><th>maximum_nights_avg_ntm</th><th>calendar_updated</th><th>has_availability</th><th>availability_30</th><th>availability_60</th><th>availability_90</th><th>availability_365</th><th>calendar_last_scraped</th><th>number_of_reviews</th><th>number_of_reviews_ltm</th><th>number_of_reviews_l30d</th><th>first_review</th><th>last_review</th><th>review_scores_rating</th><th>review_scores_accuracy</th><th>review_scores_cleanliness</th><th>review_scores_checkin</th><th>review_scores_communication</th><th>review_scores_location</th><th>review_scores_value</th><th>license</th><th>instant_bookable</th><th>calculated_host_listings_count</th><th>calculated_host_listings_count_entire_homes</th><th>calculated_host_listings_count_private_rooms</th><th>calculated_host_listings_count_shared_rooms</th><th>reviews_per_month</th></tr></thead><tbody><tr><td>20083</td><td>https://www.airbnb.com/rooms/20083</td><td>20201230040100</td><td>2020-12-30</td><td>Unique in Södermalm SOFO Stockholm</td><td>Enjoy a stay in one of the most idyllic and concealed streets in Södermalm - in the middle of Stockholm! The house from 1925 is included in a culturally protected block, formed around a beautiful park.<br /><br /><b>The space</b><br />Light and fresh one room apartment on the top floor in a house built 1925. <br /><br />The flat caters for 2 adults wishing to discover the city of Stockholm and perhaps the surrounding archipelago and its beautiful islands. Check out my 'Guidebook' for more info on local restaurants, shopping and activities!<br /><br />- Living room: with one wide bed (130 cm) and sofa bed. 42' TV and stereo<br />- Kitchen: fully equipped with plenty of space for preparing breakfast/dinners. Stove, fridge, freezer, dishwasher, microwave, toaster.<br />- Bathroom with shower.<br />- Toilet.<br />- Laundry room on the bottom floor of the building.<br />- Stunning backyard with barbeque and sitting areas.<br />- A possibility to borrow two bikes during the stay. <br /><br /</td><td>null</td><td>https://a0.muscache.com/pictures/102900/423071ef_original.jpg</td><td>75962</td><td>https://www.airbnb.com/users/show/75962</td><td>Lovisa</td><td>2010-01-31</td><td>Stockholm, Stockholm, Sweden</td><td>I'm 31, I work in the oldest now operating auction house in the world, Stockholm Auction House. I enjoy big cities, old and quirky furniture, gym training, beautiful clothes and sailing. I've been a member of Airbnb a couple of years and I'm also a host here.
# </td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Genuine</td><td> thoughtful</td><td> playful</td><td> restful and exuberant are all words that I like to incorporate into my life as much as possible!</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>",N/A,N/A,N/A,f,https://a0.muscache.com/im/users/75962/profile_pic/1359284327/original.jpg?aki_policy=profile_small,https://a0.muscache.com/im/users/75962/profile_pic/1359284327/original.jpg?aki_policy=profile_x_medium,,1,1,"['email'</td><td> 'phone'</td><td> 'reviews'</td><td> 'jumio'</td><td> 'government_id']"</td><td>t</td><td>t</td><td>null</td><td>Södermalms</td><td>null</td><td>59.30643</td><td>18.08785</td><td>Entire apartment</td><td>Entire home/apt</td><td>3</td><td>null</td><td>1 bath</td><td>1</td><td>1</td><td>"[""Cable TV""</td><td> ""Hair dryer""</td><td> ""Wifi""</td><td> ""Iron""</td><td> ""Heating""</td><td> ""Kitchen""</td><td> ""Hangers""</td><td> ""Washer""</td><td> ""Dedicated workspace""</td><td> ""Dryer""</td><td> ""Smoke alarm""</td><td> ""TV""]"</td><td>$987.00</td><td>4</td><td>28</td><td>4</td><td>4</td><td>28</td><td>28</td><td>4.0</td><td>28.0</td><td>null</td><td>t</td><td>29</td><td>59</td><td>89</td><td>364</td><td>2020-12-30</td><td>12</td><td>0</td><td>0</td><td>2010-03-28</td><td>2014-09-01</td><td>100</td><td>10</td><td>10</td><td>10</td><td>10</td><td>10</td><td>10</td><td>null</td><td>f</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0.09</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>164448</td><td>https://www.airbnb.com/rooms/164448</td><td>20201230040100</td><td>2021-01-01</td><td>Double room in central Stockholm with Wi-Fi</td><td>I am renting out a nice double room on the top floor in a large duplex apartment in the center of Stockholm at Södermalm. Close to metro and bus and walking distance to most of the sights.<br /><br /><b>The space</b><br />ROOM:<br />The room has a twin/double bed (2x90x200cm, in the US it is usually called King Size), table, wardrobe and bookshelves. The bed linen and towels are included. <br /><br />The room is located on the top floor in the apartment, where the guests share a large TV-room. In the TV-room you can also find a micro, a fridge and a water kettle to make coffee and tea. <br /><br />There is one bathroom shared between the bedrooms  ...

# %%
df_listing = spark.read.format(file_type) \
                  .option("infer_schema", infer_schema) \
                  .option("header", first_row_is_header) \
                  .option("sep", delimiter) \
                  .option("multiline", "true") \
                  .load(file_location)

display(df_listing.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>listing_url</th><th>scrape_id</th><th>last_scraped</th><th>name</th><th>description</th><th>neighborhood_overview</th><th>picture_url</th><th>host_id</th><th>host_url</th><th>host_name</th><th>host_since</th><th>host_location</th><th>host_about</th><th>host_response_time</th><th>host_response_rate</th><th>host_acceptance_rate</th><th>host_is_superhost</th><th>host_thumbnail_url</th><th>host_picture_url</th><th>host_neighbourhood</th><th>host_listings_count</th><th>host_total_listings_count</th><th>host_verifications</th><th>host_has_profile_pic</th><th>host_identity_verified</th><th>neighbourhood</th><th>neighbourhood_cleansed</th><th>neighbourhood_group_cleansed</th><th>latitude</th><th>longitude</th><th>property_type</th><th>room_type</th><th>accommodates</th><th>bathrooms</th><th>bathrooms_text</th><th>bedrooms</th><th>beds</th><th>amenities</th><th>price</th><th>minimum_nights</th><th>maximum_nights</th><th>minimum_minimum_nights</th><th>maximum_minimum_nights</th><th>minimum_maximum_nights</th><th>maximum_maximum_nights</th><th>minimum_nights_avg_ntm</th><th>maximum_nights_avg_ntm</th><th>calendar_updated</th><th>has_availability</th><th>availability_30</th><th>availability_60</th><th>availability_90</th><th>availability_365</th><th>calendar_last_scraped</th><th>number_of_reviews</th><th>number_of_reviews_ltm</th><th>number_of_reviews_l30d</th><th>first_review</th><th>last_review</th><th>review_scores_rating</th><th>review_scores_accuracy</th><th>review_scores_cleanliness</th><th>review_scores_checkin</th><th>review_scores_communication</th><th>review_scores_location</th><th>review_scores_value</th><th>license</th><th>instant_bookable</th><th>calculated_host_listings_count</th><th>calculated_host_listings_count_entire_homes</th><th>calculated_host_listings_count_private_rooms</th><th>calculated_host_listings_count_shared_rooms</th><th>reviews_per_month</th></tr></thead><tbody><tr><td>20083</td><td>https://www.airbnb.com/rooms/20083</td><td>20201230040100</td><td>2020-12-30</td><td>Unique in Södermalm SOFO Stockholm</td><td>Enjoy a stay in one of the most idyllic and concealed streets in Södermalm - in the middle of Stockholm! The house from 1925 is included in a culturally protected block, formed around a beautiful park.<br /><br /><b>The space</b><br />Light and fresh one room apartment on the top floor in a house built 1925. <br /><br />The flat caters for 2 adults wishing to discover the city of Stockholm and perhaps the surrounding archipelago and its beautiful islands. Check out my 'Guidebook' for more info on local restaurants, shopping and activities!<br /><br />- Living room: with one wide bed (130 cm) and sofa bed. 42' TV and stereo<br />- Kitchen: fully equipped with plenty of space for preparing breakfast/dinners. Stove, fridge, freezer, dishwasher, microwave, toaster.<br />- Bathroom with shower.<br />- Toilet.<br />- Laundry room on the bottom floor of the building.<br />- Stunning backyard with barbeque and sitting areas.<br />- A possibility to borrow two bikes during the stay. <br /><br /</td><td>null</td><td>https://a0.muscache.com/pictures/102900/423071ef_original.jpg</td><td>75962</td><td>https://www.airbnb.com/users/show/75962</td><td>Lovisa</td><td>2010-01-31</td><td>Stockholm, Stockholm, Sweden</td><td>I'm 31, I work in the oldest now operating auction house in the world, Stockholm Auction House. I enjoy big cities, old and quirky furniture, gym training, beautiful clothes and sailing. I've been a member of Airbnb a couple of years and I'm also a host here.
#
# Genuine, thoughtful, playful, restful and exuberant are all words that I like to incorporate into my life as much as possible!
# </td><td>N/A</td><td>N/A</td><td>N/A</td><td>f</td><td>https://a0.muscache.com/im/users/75962/profile_pic/1359284327/original.jpg?aki_policy=profile_small</td><td>https://a0.muscache.com/im
""</td><td> ""Bathtub""</td><td> ""Elevator""</td><td> ""Heating""</td><td> ""Shampoo""</td><td> ""Essentials""</td><td> ""Long term stays allowed""</td><td> ""Iron""</td><td> ""Lock on bedroom door""</td><td> ""Bed linens""</td><td> ""Refrigerator""</td><td> ""Hot water""]"</td><td>$643.00</td><td>3</td><td>300</td><td>3</td><td>3</td><td>300</td><td>300</td><td>3.0</td><td>300.0</td><td>null</td><td>t</td><td>0</td><td>0

# %%
df_listing = spark.read.format(file_type) \
                  .option("infer_schema", infer_schema) \
                  .option("header", first_row_is_header) \
                  .option("sep", delimiter) \
                  .option("multiline", "true") \
                  .option("quote", "\"") \
                  .option("escape", "\"") \
                  .load(file_location)

display(df_listing.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>listing_url</th><th>scrape_id</th><th>last_scraped</th><th>name</th><th>description</th><th>neighborhood_overview</th><th>picture_url</th><th>host_id</th><th>host_url</th><th>host_name</th><th>host_since</th><th>host_location</th><th>host_about</th><th>host_response_time</th><th>host_response_rate</th><th>host_acceptance_rate</th><th>host_is_superhost</th><th>host_thumbnail_url</th><th>host_picture_url</th><th>host_neighbourhood</th><th>host_listings_count</th><th>host_total_listings_count</th><th>host_verifications</th><th>host_has_profile_pic</th><th>host_identity_verified</th><th>neighbourhood</th><th>neighbourhood_cleansed</th><th>neighbourhood_group_cleansed</th><th>latitude</th><th>longitude</th><th>property_type</th><th>room_type</th><th>accommodates</th><th>bathrooms</th><th>bathrooms_text</th><th>bedrooms</th><th>beds</th><th>amenities</th><th>price</th><th>minimum_nights</th><th>maximum_nights</th><th>minimum_minimum_nights</th><th>maximum_minimum_nights</th><th>minimum_maximum_nights</th><th>maximum_maximum_nights</th><th>minimum_nights_avg_ntm</th><th>maximum_nights_avg_ntm</th><th>calendar_updated</th><th>has_availability</th><th>availability_30</th><th>availability_60</th><th>availability_90</th><th>availability_365</th><th>calendar_last_scraped</th><th>number_of_reviews</th><th>number_of_reviews_ltm</th><th>number_of_reviews_l30d</th><th>first_review</th><th>last_review</th><th>review_scores_rating</th><th>review_scores_accuracy</th><th>review_scores_cleanliness</th><th>review_scores_checkin</th><th>review_scores_communication</th><th>review_scores_location</th><th>review_scores_value</th><th>license</th><th>instant_bookable</th><th>calculated_host_listings_count</th><th>calculated_host_listings_count_entire_homes</th><th>calculated_host_listings_count_private_rooms</th><th>calculated_host_listings_count_shared_rooms</th><th>reviews_per_month</th></tr></thead><tbody><tr><td>20083</td><td>https://www.airbnb.com/rooms/20083</td><td>20201230040100</td><td>2020-12-30</td><td>Unique in Södermalm SOFO Stockholm</td><td>Enjoy a stay in one of the most idyllic and concealed streets in Södermalm - in the middle of Stockholm! The house from 1925 is included in a culturally protected block, formed around a beautiful park.<br /><br /><b>The space</b><br />Light and fresh one room apartment on the top floor in a house built 1925. <br /><br />The flat caters for 2 adults wishing to discover the city of Stockholm and perhaps the surrounding archipelago and its beautiful islands. Check out my 'Guidebook' for more info on local restaurants, shopping and activities!<br /><br />- Living room: with one wide bed (130 cm) and sofa bed. 42' TV and stereo<br />- Kitchen: fully equipped with plenty of space for preparing breakfast/dinners. Stove, fridge, freezer, dishwasher, microwave, toaster.<br />- Bathroom with shower.<br />- Toilet.<br />- Laundry room on the bottom floor of the building.<br />- Stunning backyard with barbeque and sitting areas.<br />- A possibility to borrow two bikes during the stay. <br /
>Södermalm</td><td>2</td><td>2</td><td>['email', 'phone', 'reviews', 'jumio', 'government_id']</td><td>t</td><td>t</td><td>null</td><td>Södermalms</td><td>null</td><td>59.31268</td><td>18.06258</td><td>Private room in apartment</td><td>Private room</td><td>2</td><td>null</td><td>1 shared bath</td><td>1</td><td>2</td><td>["Luggage dropoff allowed", "Dedicated workspace", "Smoke alarm", "Wifi", "TV", "Hangers", "Dryer", "Dishes and silverware", "Microwave", "Extra pillows and blankets", "Washer", "Hair dryer", "Bathtub", "Elevator", "Heating", "Shampoo", "Essentials", "Long term stays allowed", "Iron", "Lock on bedroom door", "Bed linens", "Refrigerator", "Hot water"]</td><td>$643.00</td><td>3</td><td>300</td><td>3</td><td>3</td><td>300</td><td>300</td><td>3.0</td><td>300.0</td><td>null</td><td>t</td><td>0</td><td>0</td><td>0</td><td>0</td><td>2021-01-01</td><td>320</td><td>2</td><td>0</td><td>2011-08-24</td><td>2020-01-29</td><td>97</td><td>10</td><td>10</td><td>10</td><td>10</td><td>10</td><td>10</td><td>null</td><td>t</td><td>

# %%
# %sql

drop table if exists listing
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
listing_table = "listing"
df_listing.write.format("parquet").saveAsTable(listing_table)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_listing.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: string (nullable = true)
# -- listing_url: string (nullable = true)
# -- scrape_id: string (nullable = true)
# -- last_scraped: string (nullable = true)
# -- name: string (nullable = true)
# -- description: string (nullable = true)
# -- neighborhood_overview: string (nullable = true)
# -- picture_url: string (nullable = true)
# -- host_id: string (nullable = true)
# -- host_url: string (nullable = true)
# -- host_name: string (nullable = true)
# -- host_since: string (nullable = true)
# -- host_location: string (nullable = true)
# -- host_about: string (nullable = true)
# -- host_response_time: string (nullable = true)
# -- host_response_rate: string (nullable = true)
# -- host_acceptance_rate: string (nullable = true)
# -- host_is_superhost: string (nullable = true)
# -- host_thumbnail_url: string (nullable = true)
# -- host_picture_url: string (nullable = true)
# -- host_neighbourhood: string (nullable = true)
# -- host_listings_count: string (nullable = true)
# -- host_total_listings_count: string (nullable = true)
# -- host_verifications: string (nullable = true)
# -- host_has_profile_pic: string (nullable = true)
# -- host_identity_verified: string (nullable = true)
# -- neighbourhood: string (nullable = true)
# -- neighbourhood_cleansed: string (nullable = true)
# -- neighbourhood_group_cleansed: string (nullable = true)
# -- latitude: string (nullable = true)
# -- longitude: string (nullable = true)
# -- property_type: string (nullable = true)
# -- room_type: string (nullable = true)
# -- accommodates: string (nullable = true)
# -- bathrooms: string (nullable = true)
# -- bathrooms_text: string (nullable = true)
# -- bedrooms: string (nullable = true)
# -- beds: string (nullable = true)
# -- amenities: string (nullable = true)
# -- price: string (nullable = true)
# -- minimum_nights: string (nullable = true)
# -- maximum_nights: string (nullable = true)
# -- minimum_minimum_nights: string (nullable = true)
# -- maximum_minimum_nights: string (nullable = true)
# -- minimum_maximum_nights: string (nullable = true)
# -- maximum_maximum_nights: string (nullable = true)
# -- minimum_nights_avg_ntm: string (nullable = true)
# -- maximum_nights_avg_ntm: string (nullable = true)
# -- calendar_updated: string (nullable = true)
# -- has_availability: string (nullable = true)
# -- availability_30: string (nullable = true)
# -- availability_60: string (nullable = true)
# -- availability_90: string (nullable = true)
# -- availability_365: string (nullable = true)
# -- calendar_last_scraped: string (nullable = true)
# -- number_of_reviews: string (nullable = true)
# -- number_of_reviews_ltm: string (nullable = true)
# -- number_of_reviews_l30d: string (nullable = true)
# -- first_review: string (nullable = true)
# -- last_review: string (nullable = true)
# -- review_scores_rating: string (nullable = true)
# -- review_scores_accuracy: string (nullable = true)
# -- review_scores_cleanliness: string (nullable = true)
# -- review_scores_checkin: string (nullable = true)
# -- review_scores_communication: string (nullable = true)
# -- review_scores_location: string (nullable = true)
# -- review_scores_value: string (nullable = true)
# -- license: string (nullable = true)
# -- instant_bookable: string (nullable = true)
# -- calculated_host_listings_count: string (nullable = true)
# -- calculated_host_listings_count_entire_homes: string (nullable = true)
# -- calculated_host_listings_count_private_rooms: string (nullable = true)
# -- calculated_host_listings_count_shared_rooms: string (nullable = true)
# -- reviews_per_month: string (nullable = true)
#
# </div>

# %%
import pyspark.sql.functions as F
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from listing limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>host_id</th><th>host_name</th><th>neighbourhood_group</th><th>neighbourhood</th><th>latitude</th><th>longitude</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>last_review</th><th>reviews_per_month</th><th>calculated_host_listings_count</th><th>availability_365</th></tr></thead><tbody><tr><td>20083</td><td>Unique in Södermalm SOFO Stockholm</td><td>75962</td><td>Lovisa</td><td>null</td><td>Södermalms</td><td>59.30643</td><td>18.08785</td><td>Entire home/apt</td><td>987</td><td>4</td><td>12</td><td>2014-09-01</td><td>0.09</td><td>1</td><td>364</td></tr><tr><td>164448</td><td>Double room in central Stockholm with Wi-Fi</td><td>784312</td><td>Li</td><td>null</td><td>Södermalms</td><td>59.31268</td><td>18.06258</td><td>Private room</td><td>643</td><td>3</td><td>320</td><td>2020-01-29</td><td>2.81</td><td>2</td><td>0</td></tr><tr><td>170651</td><td>Petit Charm Rooftop next to heaven</td><td>814021</td><td>Marie</td><td>null</td><td>Södermalms</td><td>59.31568</td><td>18.03138</td><td>Entire home/apt</td><td>694</td><td>4</td><td>34</td><td>2020-03-09</td><td>0.30</td><td>1</td><td>317</td></tr><tr><td>206221</td><td>Doubleroom at Södermalm &trendySofo</td><td>1022374</td><td>Elisabeth</td><td>null</td><td>Södermalms</td><td>59.31226</td><td>18.07942</td><td>Shared room</td><td>669</td><td>3</td><td>79</td><td>2019-12-08</td><td>0.71</td><td>1</td><td>304</td></tr><tr><td>220851</td><td>One room in appartement</td><td>412283</td><td>Fredric</td><td>null</td><td>Kungsholmens</td><td>59.33376</td><td>18.03816</td><td>Private room</td><td>600</td><td>3</td><td>48</td><td>2020-10-02</td><td>0.43</td><td>1</td><td>333</td></tr></tbody></table></div>

# %%
from pyspark.sql.types import *

# file location and type
file_location = "dbfs:/mnt/s3data/neighbourhoods.csv"
file_type = "csv"

# CV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

neighbourhoodSchema = StructType([
  StructField("neighbourhood_group", StringType(), True),
  StructField("neighbourhood", StringType(), True),
])

# The applied options are for CSV files. 
df_neighbourhoods = spark.read.format(file_type) \
                  .option("schema", neighbourhoodSchema) \
                  .option("header", first_row_is_header) \
                  .option("sep", delimiter) \
                  .option("multiline", "true") \
                  .option("quote", "\"") \
                  .option("escape", "\"") \
                  .load(file_location)

display(df_neighbourhoods.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>neighbourhood_group</th><th>neighbourhood</th></tr></thead><tbody><tr><td>null</td><td>Älvsjö</td></tr><tr><td>null</td><td>Bromma</td></tr><tr><td>null</td><td>Enskede-Årsta-Vantörs</td></tr><tr><td>null</td><td>Farsta</td></tr><tr><td>null</td><td>Hägersten-Liljeholmens</td></tr></tbody></table></div>

# %%
listing_table = "neighbourhood"
df_neighbourhoods.write.mode("overwrite").format("parquet").saveAsTable(listing_table)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# file location and type
file_location = "dbfs:/mnt/s3data/reviews.csv"
file_type = "csv"

# CV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","


# The applied options are for CSV files. 
df_reviews = spark.read.format(file_type) \
                  .option("inferSchema", infer_schema) \
                  .option("header", first_row_is_header) \
                  .option("sep", delimiter) \
                  .option("wholeFile", "true") \
                  .option("multiline", 'true') \
                  .load(file_location)

display(df_reviews.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>listing_id</th><th>id</th><th>date</th><th>reviewer_id</th><th>reviewer_name</th><th>comments</th></tr></thead><tbody><tr><td>20083</td><td>31750</td><td>2010-03-28</td><td>76930</td><td>Floor</td><td>We stayed at Lovisa's place during 4 days in March, and had a really good time. It is located in the nicest, most trendy area of Stockholm, close to restaurants and shops, but really nice and quiet next to a park. The appartement is clean and has all you need. I would recommend it without any doubt! </td></tr><tr><td>20083</td><td>41340</td><td>2010-05-10</td><td>72535</td><td>Lauren</td><td>I rented this flat for my parents while they were visiting me in Sweden.  It worked out great!  Lovisa's place was cute, clean, and located in a great area of Södermalm - still close to restaurants but in a quiet area next to a park.  Great place to rent - Enjoy!</td></tr><tr><td>20083</td><td>301747</td><td>2011-06-07</td><td>41538</td><td>Barbara</td><td>We just loved Lovisas flat!  The perfect place for one or two personnes: freshly renovated, perfectly clean, very quiet and modern. The appartment is located in a very lively and popular area of Stockholm with lots of cafes and stores and just a short distance from the old town.
# Lovisa is a very friendly and helpful host. Using her bikes was a great thing  to explore Stockholm. Thanks for that, Lovisa! We highly recommend her place for your stay in Stockholm. </td></tr><tr><td>20083</td><td>377986</td><td>2011-07-17</td><td>669200</td><td>Emma</td><td>Lovisa's flat is an amazing place to stay in Stockholm - located in a 1920s housing development on a small hill and surrounded by parks, the area feels calm and secluded even though it's minutes from Skanstull's underground station, bars, restaurants and great shopping. The flat itself is beautiful, with lots of light, wooden floors and a fantastic kitchen, and Lovisa is a very helpful and organised host. I would definitely stay there again, and can thoroughly recommend it. </td></tr><tr><td>20083</td><td>744050</td><td>2011-11-26</td><td>1107665</td><td>David</td><td>Lovisa and her apartment are fantastic! She is a wonderful host always happy to provide helpful tips on the apartment and the city. Easy to get to, close enough to the city to walk, and nightlife is even closer. I would recommend to all. I wish I could take the shower home!! Would love to stay again.</td></tr></tbody></table></div>

# %%
df_reviews.repartition(1).write.format("parquet").option("path","dbfs:/mnt/s3data/reviews_fixed").saveAsTable("reviews_fixed")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dbutils.fs.ls("/mnt/s3data"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/s3data/listings.csv</td><td>listings.csv</td><td>5962518</td></tr><tr><td>dbfs:/mnt/s3data/neighbourhoods.csv</td><td>neighbourhoods.csv</td><td>242</td></tr><tr><td>dbfs:/mnt/s3data/reviews.csv</td><td>reviews.csv</td><td>22432792</td></tr><tr><td>dbfs:/mnt/s3data/reviews_fixed/</td><td>reviews_fixed/</td><td>0</td></tr></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
